# %%
#importing the python pandas module
import pandas as pds

# %%
food_data = pds.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

food_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

food_data.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
#QUestion 12

#Answer the following questions based on the African food production dataset 
#provided by the FAO website already provided

#What is the total sum of Wine produced in 2015 and 2018 respectively?

#Hint: Perform a groupby sum aggregation on ‘Item’

q12 = food_data.groupby('Item')['Wine']

#WIne not found jareeeeeee

q12
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 10
#       1 #QUestion 12
#       2
#       3 #Answer the following questions based on the African food production dataset
#    (...)
#       7
#       8 #Hint: Perform a groupby sum aggregation on ‘Item’
# ---> 10 q12 = food_data.groupby('Item')['Wine']
#      12 #WIne not found jareeeeeee
#      14 q12
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1961, in DataFrameGroupBy.__getitem__(self, key)
#    1954 if isinstance(key, tuple) and len(key) > 1:
#    1955     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1956     # valid syntax, so don't raise
#    1957     raise ValueError(
#    1958         "Cannot subset columns with a tuple with more than one element. "
#    1959         "Use a list instead."
#    1960     )
# ...

# %%
import matplotlib.pyplot as plt

# Question 7

#What is the total Protein supply quantity in Madagascar in 2015?

# Plot a graph to identify that quickly 
# VIsualizaing th dataset will help sort things out

q7 = food_data.groupby['Y2017'].sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 10
#       1 import matplotlib.pyplot as plt
#       3 # Question 7
#       4
#       5 #What is the total Protein supply quantity in Madagascar in 2015?
#       6
#       7 # Plot a graph to identify that quickly
#       8 # VIsualizaing th dataset will help sort things out
# ---> 10 q7 = food_data.groupby['Y2017'].sum().sort_values()
#
# TypeError: 'method' object is not subscriptable

# %%
# Question 1
q1 = food_data['Y2017']

quk.mean() #SInce mea is found in the options, why find other???
#THough, if i still intend to find that, i can just use a method for that
# Out:
# 140.9177648602722

# %%
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  
#Which of these Areas had the 7th lowest sum in 2017?

# %%
# Which year had the least correlation with ‘Element Code’?

q6 = food_data['Element Code'].corr("pearson")

#min_correlation = correlation_matrix.min().min()

q6

#min_correlation
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20500\3540827903.py in ?()
#       1 # Which year had the least correlation with ‘Element Code’?
#       2
# ----> 3 q6 = food_data['Element Code'].corr("pearson")
#       4
#       5 #min_correlation = correlation_matrix.min().min()
#       6
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py in ?(self, other, method, min_periods)
#    2847         >>> s2 = pd.Series([1, 2, 3], index=[2, 1, 0])
#    2848         >>> s1.corr(s2)
#    2849         -1.0
#    2850         """  # noqa: E501
# -> 2851         this, other = self.align(other, join="inner", copy=False)
#    2852         if len(this) == 0:
#    2853             return np.nan
#    2854
#
# ...

# %%
# Qeustion 18
#Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  
#Which of these Areas had the highest sum in 2017?

q18 = food_data.groupby('Area')['Y2017'].sum().sort_values()

q18
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
# Question 17
# Perform a groupby operation on ‘Element’.  
# What year has the highest sum of Stock Variation?

element = food_data.groupby('Element').sum()
element[:'Stock Variation'].sum()
# Out:
# Area Code                                                 8126219
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               162165537
# Item            PopulationCereals - Excluding BeerWheat and pr...
# Element Code                                            229595897
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                  6933085.13
# Y2015                                                  6973910.23
# Y2016                                                  7027276.65
# Y2017                                                  7262997.19
# Y2018                                                  7413934.96
# dtype: object

# %%
#food_data.groupby('Y2017')['Area'].sum()

no_of_array = food_data['Area'].unique()

no_of_array
# Out:
# array(['Algeria', 'Angola', 'Benin', 'Botswana', 'Burkina Faso',
#        'Cabo Verde', 'Cameroon', 'Central African Republic', 'Chad',
#        'Comoros', 'Congo', "Côte d'Ivoire", 'Djibouti', 'Egypt',
#        'Eswatini', 'Ethiopia', 'Ethiopia PDR', 'Gabon', 'Gambia', 'Ghana',
#        'Guinea', 'Guinea-Bissau', 'Kenya', 'Lesotho', 'Liberia',
#        'Madagascar', 'Malawi', 'Mali', 'Mauritania', 'Mauritius',
#        'Morocco', 'Mozambique', 'Namibia', 'Niger', 'Nigeria', 'Rwanda',
#        'Sao Tome and Principe', 'Senegal', 'Seychelles', 'Sierra Leone',
#        'South Africa', 'Sudan', 'Sudan (former)', 'Togo', 'Tunisia',
#        'Uganda', 'United Republic of Tanzania', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
len(no_of_array)
# Out:
# 49

# %%
# QUestion 14
y = [(2, 4), (7, 8), (1, 5, 9)]

x = y[1][1]

x
# Out:
# 8

# %%
#QUestion 15

my_tuppy = (1,2,5,8)

my_tuppy[2] = 6 #Raised TypeError because tuple is a immutable.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 5
#       1 #QUestion 15
#       3 my_tuppy = (1,2,5,8)
# ----> 5 my_tuppy[2] = 6 #Raised TypeError because tuple is a immutable.
#
# TypeError: 'tuple' object does not support item assignment

# %%
# QUestion 16

lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

#How do you create a pandas DataFrame using this list, to look like the table below?

df = pds.DataFrame(lst, columns=col, index = [1,2,3])

df
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
food_data.iloc[:]
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
import numpy as np

array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

array[ : 1, 1 : ] #Still finding out the error here.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 9
#       1 import numpy as np
#       3 array  = ([[94, 89, 63],
#       4
#       5              [93, 92, 48],
#       6
#       7              [92, 94, 56]])
# ----> 9 array[ : 1, 1 : ] #Still finding out the error here.
#
# TypeError: list indices must be integers or slices, not tuple

# %%
#array[:1,1: ]

array[ : 2,2, ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 #array[:1,1: ]
# ----> 3 array[ : 2,2, ]
#
# TypeError: list indices must be integers or slices, not tuple
